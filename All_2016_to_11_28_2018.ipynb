# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
data = pd.read_csv("/Users/Stacy/Documents/WebDevelopment/projects/spd_project/crime_reporting/data/All_2016_to_11_28_2018.csv")
data = pd.DataFrame(data)

# %%
data.columns = ['cad_num', 'event_clearing', 'call_type', 'priority', 
                'initial_call_type', 'final_call_type', 'original_time_queued',
               'arrived_time', 'precinct', 'sector', 'beat']

# %%
data.head()
# Out:
#          cad_num           event_clearing call_type  priority  \
# 0  2016000000002      ASSISTANCE RENDERED    ONVIEW         7
# 1  2016000000001  PROBLEM SOLVING PROJECT    ONVIEW         7
# 2  2016000000003      ASSISTANCE RENDERED    ONVIEW         3
# 3  2015000451943      ASSISTANCE RENDERED       911         1
# 4  2016000000004      ASSISTANCE RENDERED    ONVIEW         7
#
#                               initial_call_type  \
# 0  PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY
# 1  PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY
# 2        SUSPICIOUS PERSON, VEHICLE OR INCIDENT
# 3     SHOTS - IP/JO - INCLUDES HEARD/NO ASSAULT
# 4  PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY
#
#                             final_call_type    original_time_queued  \
# 0       --PREMISE CHECKS - CRIME PREVENTION  01/01/2016 12:00:04 AM
# 1       --PREMISE CHECKS - CRIME PREVENTION  01/01/2016 12:00:04 AM
# 2  --SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON  01/01/2016 12:00:06 AM
# 3                     --DISTURBANCE - NOISE  01/01/2016 12:00:11 AM
# 4       --PREMISE CHECKS - CRIME PREVENTION  01/01/2016 12:00:38 AM
#
#                  arrived_time precinct  sector beat
# 0  Jan  1 2016 12:00:04:000AM     EAST  EDWARD   E1
# 1  Jan  1 2016 12:00:04:000AM    SOUTH  ROBERT   R3
# 2  Jan  1 2016 12:00:06:000AM    SOUTH   OCEAN   O1
# 3  Jan  1 2016 12:07:23:000AM    SOUTH     SAM   S3
# 4  Jan  1 2016 12:00:38:000AM     WEST    KING   K2

# %%
data.dtypes
# Out:
# cad_num                  int64
# event_clearing          object
# call_type               object
# priority                 int64
# initial_call_type       object
# final_call_type         object
# original_time_queued    object
# arrived_time            object
# precinct                object
# sector                  object
# beat                    object
# dtype: object

# %%
data['original_time_queued'] = pd.to_datetime(data.original_time_queued)

# %%
data['arrived_time'] = pd.to_datetime(data.arrived_time, format='%b %d %Y %I:%M:%S:%f%p')

# %%
sexual_assault_terms = ['CSEC', 'LEWD', 'MOLESTING', 'RAPE']
sexual_assault_terms_joined = '|'.join(sexual_assault_terms)
sexual_assault_terms_joined
# Out:
# 'CSEC|LEWD|MOLESTING|RAPE'

# %%
data['is_sexual_assault'] = data['final_call_type'].str.contains(sexual_assault_terms_joined, case=False)
data['is_rape'] = data['final_call_type'].str.contains('ACQUAINTANCE|STRANGER', case=False)

# %%
data.count()
# Out:
# cad_num                 1226233
# event_clearing          1226233
# call_type               1226233
# priority                1226233
# initial_call_type       1226233
# final_call_type         1226233
# original_time_queued    1226233
# arrived_time            1226233
# precinct                1226233
# sector                  1218157
# beat                    1226233
# is_sexual_assault       1226233
# is_rape                 1226233
# dtype: int64

# %%
data.loc[data['is_sexual_assault'] == True, ['final_call_type', 'is_sexual_assault']]
# Out:
#                                          final_call_type  is_sexual_assault
# 209                  --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 348                  --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 402                  --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 597             --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 747                    --SEX OFFENSES (RAPE) - MOLESTING               True
# 826                --RAPE - KNOWN SUSPECT (ACQUAINTANCE)               True
# 1052               --RAPE - KNOWN SUSPECT (ACQUAINTANCE)               True
# 1112                 --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 1294            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1999      LEWD -  (EXPOSING, FLASHING, URINATING IN PUB)               True
# 2219            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 2481            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 2557            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 2757                   --SEX OFFENSES (RAPE) - MOLESTING               True
# 2882                   --SEX OFFENSES (RAPE) - MOLESTING               True
# 3129            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 3635                 --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 4187               --RAPE - KNOWN SUSPECT (ACQUAINTANCE)               True
# 4391                 --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 4597            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 4867                 --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 5256            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 6382                   --SEX OFFENSES (RAPE) - MOLESTING               True
# 6403                 --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 6733            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 7312                 --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 7781                   --SEX OFFENSES (RAPE) - MOLESTING               True
# 7796            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 8370            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 8380            --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# ...                                                  ...                ...
# 1221121  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1221262         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1221313         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1221418              --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 1221463         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1221547              --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 1222435              --RAPE - UNKNOWN SUSPECT (STRANGER)               True
# 1222611            --RAPE - KNOWN SUSPECT (ACQUAINTANCE)               True
# 1222737  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222741  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222746  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222747  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222755  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222762  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222784  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222789  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222797  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222836  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222843  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222846            --RAPE - KNOWN SUSPECT (ACQUAINTANCE)               True
# 1222858  --SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER               True
# 1222916         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1223699         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1223749         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1223902                --SEX OFFENSES (RAPE) - MOLESTING               True
# 1223974         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1224136                --SEX OFFENSES (RAPE) - MOLESTING               True
# 1224952         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1226035         --SEX OFFENSES (NON-RAPE) - LEWD CONDUCT               True
# 1226220              --RAPE - UNKNOWN SUSPECT (STRANGER)               True
#
# [6301 rows x 2 columns]

# %%
# Need to confirm with SPD: call type 'sex offense (rape) - molesting'
# 6069 rows × 2 columns
data.loc[data['is_rape'] == True, ['final_call_type', 'is_rape']]
# Out:
#                                final_call_type  is_rape
# 209        --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 348        --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 402        --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 826      --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1052     --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1112       --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 3635       --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 4187     --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 4391       --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 4867       --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 6403       --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 7312       --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 8469       --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 8706     --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 11861      --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 12470    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 13379    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 13638    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 13787    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 14696      --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 15193      --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 17763    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 17845      --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 18691      --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 18939      --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 21387    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 21841    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 21954    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 22319    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 23196    --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# ...                                        ...      ...
# 1202839  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1203195  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1203456  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1203916    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1205259  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1205391    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1205954  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1207939    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1209242  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1209438  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1210559  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1211591  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1211847  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1212768  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1214095  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1214632  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1217593    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1219065  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1219195  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1220201    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1220592  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1220925  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1220926  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1221040  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1221418    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1221547    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1222435    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
# 1222611  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1222846  --RAPE - KNOWN SUSPECT (ACQUAINTANCE)     True
# 1226220    --RAPE - UNKNOWN SUSPECT (STRANGER)     True
#
# [1501 rows x 2 columns]

# %%
data.dtypes
# Out:
# cad_num                          int64
# event_clearing                  object
# call_type                       object
# priority                         int64
# initial_call_type               object
# final_call_type                 object
# original_time_queued    datetime64[ns]
# arrived_time            datetime64[ns]
# precinct                        object
# sector                          object
# beat                            object
# is_sexual_assault                 bool
# is_rape                           bool
# dtype: object
